# %% [markdown]
# 해빙의 감소추세를 알아보자. (최근 30년만 일단 살펴보자.)

# %%
import pandas as pd
import numpy as np 
from matplotlib import pyplot as plt
train = pd.read_csv('data/weekly_train.csv')
test = pd.read_csv('data/public_weekly_test.csv')
year_search = 30
train_data_path = 'data/weekly_train/' + train.tail(52*year_search)['week_file_nm'].values
train_data = [] 
for paths in train_data_path :
    train_data.append(paths)
print(train_data_path)
# Out:
# ['data/weekly_train/10614.npy' 'data/weekly_train/10615.npy'
#  'data/weekly_train/10616.npy' ... 'data/weekly_train/12171.npy'
#  'data/weekly_train/12172.npy' 'data/weekly_train/12173.npy']

# %%
plt.figure(figsize=(20, 50))
for iter in range(52 * year_search) : 
    fig.add_subplot(52 * year_search / 4, 4, iter + 1)
    plt.imshow(np.load(train_data_path[iter])[-1])
    plt.show()
# Out:
# ipykernel_launcher:3: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
